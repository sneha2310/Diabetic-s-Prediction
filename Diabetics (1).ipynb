# %% [markdown]
# **Support Vector** **Machine**

# %% [markdown]
# “Support Vector Machine” (SVM) is a supervised machine learning algorithm which can be used for both classification or regression challenges. However,  it is mostly used in classification problems. In the SVM algorithm, we plot each data item as a point in n-dimensional space (where n is number of features you have) with the value of each feature being the value of a particular coordinate. Then, we perform classification by finding the hyper-plane that differentiates the two classes very well

# %% [markdown]
# **Logistics Regression**

# %% [markdown]
# Logistic regression is another technique borrowed by machine learning from the field of statistics.
#
# It is the go-to method for binary classification problems (problems with two class values)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Data collection and Analysis

# %%
dia = pd.read_csv(r'drive/My Drive/Project 4/diabetes.csv')

# %%
#statistical measure of data
dia.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
dia.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dia.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
dia.shape  #(rows,columns)
# Out:
# (768, 9)

# %%
dia['Outcome'].value_counts() # 0= non-diabetics
                              # 1= diabetics
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
dia.groupby('Outcome').mean() # Groupby on basis of outcomes
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
# seperating the data and labels
X= dia.drop(columns= "Outcome", axis=1)
Y= dia["Outcome"]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
Y.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# Standarize the data

# %%
#LabelEncoder should be used for the labels, in order to have labels for n categories
# replaced with integers from 1 to n. You should do this if it is not already done.
# StandardScaler is meant to be used, eventually, for the training and test data but
# nor for the labels...mean=0 and variance=1
se = StandardScaler()

# %%
data = se.fit_transform(X)

# %%
print(data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X =data

# %% [markdown]
# Train Test Split

# %%
#statify: if we don't use stratify then entire diabetics dataset goes into X_train and non-diabetics 
# into X_test so for avoiding it we use stratify=Y
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test =train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# Taining the model

# %% [markdown]
# Support Vector Machine

# %%
#svm = support vector machine
# kernel = linear model
#SVC = support vector classifier
classifier = svm.SVC(kernel="linear")

# %%
# training the support vector machine classifier
model = classifier.fit(X_train,Y_train)

# %%
print(model)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression  
LR = LogisticRegression()
LR.fit(X_train, Y_train)
print(LR)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
x_train_prediction = LR.predict(X_train)
training_data_accuracy = accuracy_score(x_train_prediction, Y_train)

# %%
print("Accuracy score of training data :" ,training_data_accuracy)
# Out:
# Accuracy score of training data : 0.7850162866449512

# %% [markdown]
# Model Evaluation

# %%
#accuracy scores on training data
x_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(x_train_prediction, Y_train)

# %%
print("Accuracy score of training data :" ,training_data_accuracy)
# Out:
# Accuracy score of training data : 0.7866449511400652

# %%
# accuracy socres on test data
x_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(x_test_prediction, Y_test)

# %%
print("Acccuracy score of testing data :" ,test_data_accuracy)
# Out:
# Acccuracy score of training data : 0.7727272727272727

# %%
#This accuracy is good. If accuracy of training > accuracy of test data then it becomes overfitting

# %% [markdown]
# Predictive system on input data

# %%
input_data =(5,116,74,0,0,25.6,0.201,30)
# we change thr list datatype of input_data in numpy array because the calculation in this much easier
input_as_numpy = np.asarray(input_data)
#reshape the array as we are predicting for one instance
input_reshaped = input_as_numpy.reshape(1,-1) # we give onlyy one instance through (1,-1)
#standarise the data
std_data = se.fit_transform(input_reshaped)
print(std_data)
# Out:
# [[0. 0. 0. 0. 0. 0. 0. 0.]]

# %%
predict = LR.predict(std_data)
if predict[0]== 0:
  print("Person has no diabetics: ",*predict)
else:
  print("Person has diabetics: ",*predict)
# Out:
# Person has no diabetics:  0
